# %% [markdown]
# <img src="assets/BIP – AI-Driven Service Innovation Summer School 2025.png" alt="BIP – AI-Driven Service Innovation Summer School 2025"/>
#
# # Introduction to <b>SAS Viya Workbench for Learners</b>
# Part 4: estimated time to complete 15 minutes
#
# ## Learning objectives related to this document:
# * Understand that you can use genAI to produce python code
# * Understand there are limitations when using AI and genAI

# %% [markdown]
# ##### Practice 7
#
# Let's assume we want to create some python code to analize the files available on kaggle with information
# about F1 races from 2014 till 2024. The kaggle page that describes the available files is:
#     <a href="https://www.kaggle.com/datasets/rohanrao/formula-1-world-championship-1950-2020">Formula 1 World Championship (1950 - 2024)</a>
#
# Although you can use many genAI or LLM-based applications to create python code we advise you to use perplexity.ai
# for this practice.
#
# #### How does perplexity work?
# When you ask Perplexity a question, it uses advanced AI to search the internet in real time, gathering insights
# from top-tier sources. It then distills this information into a clear, concise summary, delivering exactly what
# you need in an easy-to-understand, conversational tone.
#
# You can start by going to <a href="https://www.perplexity.ai/">perplexity.ai</a>.
# This opens a web page with a box where you are invited to ask anything ...
# Copy-and-paste the *prompt* included below in that box.
#
# The kaggle URL https://www.kaggle.com/datasets/rohanrao/formula-1-world-championship-1950-2020 provides
# information on F1 datasets. Can you provide a python code sample I can execute to analise the top 3 drivers
# and top 2 constructors for each year in the years from 2019 till 2024. Use
# https://raw.githubusercontent.com/AkhilRD/F1-Explorative-Analysis/main/  in front of the csv-filename
# when using pd.read.csv and remember to set all variable names to lowercase characters.

# %%
# This code cell can be used for practice 7 described above
# Include the code generated by perplexity below

# %% [markdown]
# #### Are you interested in learning more about AI, LLMs, robotics and genAI ?
#
# [![](https://www.josvandervelden.com/myVideos/podcast_LLMs_are_useful_liars.jpg)](https://youtu.be/DDaqOF9GQNI)
#
# [![](https://www.josvandervelden.com/myVideos/Google_deepmind.jpg)](https://youtu.be/Rgwty6dGsYI)
#
# ## We hope you enjoyed this session.
#
# Have fun, be curious and never trust AI without checking!
# Trust yourself, your capacity to learn and act ethically.
